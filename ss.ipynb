# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
#url ='https://www.boxofficemojo.com/chart/top_lifetime_gross/?area=XWW'
url='https://www.billboard.com/charts/billboard-global-200/'

# %%
response= requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content)

# %%
soup.select('h3 a')
# Out:
# [<a class="c-title__link lrv-a-unstyle-link" href="#">
#
#
#  					Ordinary
#  					</a>,
#  <a class="c-title__link lrv-a-unstyle-link" href="https://www.billboard.com/music/chart-beat/alex-warren-ordinary-global-charts-number-one-june-21-1236000380/">
#
#
#  					Alex Warren’s ‘Ordinary’ Holds at No. 1 on Global Charts, Sabrina Carpenter’s ‘Manchild’ Debuts at No. 2
#  					</a>,
#  <a class="c-link lrv-a-unstyle-link account-link lrv-u-font-size-32@desktop lrv-u-font-size-20 lrv-u-font-weight-bold u-padding-a-1@desktop-max lrv-u-padding-b-050" href="#">
#  	Account</a>,
#  <a class="c-link lrv-a-unstyle-link a-font-primary-bold lrv-u-font-size-28@desktop-xl lrv-u-font-size-18 lrv-u-color-grey:hover u-padding-a-1@desktop-max lrv-u-padding-b-050" href="/charts/">
#  	Charts</a>,
# ...

# %%
soup.select('td a')
# Out:
# []

# %%
movie_name=[]

# %%
movie_year=[]

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup.select ('h3.c-title')
# Out:
# [<h3 class="c-title a-font-primary-bold-l a-font-primary-bold-m@mobile-max lrv-u-color-black u-color-white@mobile-max lrv-u-margin-r-150" id="">
#  <a class="c-title__link lrv-a-unstyle-link" href="#">
#
#
#  					Ordinary
#  					</a>
#  </h3>,
#  <h3 class="c-title a-font-primary-m lrv-u-color-brand-primary:hover" id="title-of-a-story">
#  <a class="c-title__link lrv-a-unstyle-link" href="https://www.billboard.com/music/chart-beat/alex-warren-ordinary-global-charts-number-one-june-21-1236000380/">
#
#
#  					Alex Warren’s ‘Ordinary’ Holds at No. 1 on Global Charts, Sabrina Carpenter’s ‘Manchild’ Debuts at No. 2
#  					</a>
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-s u-letter-spacing-0026 lrv-u-color-black" id="title-of-a-story">
#
#
#
#
#  					Gains in Weekly Performance
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-s u-letter-spacing-0026 lrv-u-color-black" id="title-of-a-story">
#
#
#
#
#  					Additional Awards
#
#  </h3>,
# ...

# %%
#yrs= soup.select("td a")[1::2]
#movies=soup.select("td a")[0::2]
song_title= soup.select('h3.a-no-trucate')[0::2]
art= soup.select('span.a-no-trucate')[0::2]

# %%
#yrs= [i.get_text() for i in yrs]
#movies= [i.get_text()for i in movies]
tp_song= [i.get_text(strip=True) for i in song_title]
artits= [i.get_text(strip=True) for i in art]

# %%
tp_song
# Out:
# ['Ordinary',
#  'Die With A Smile',
#  'Birds Of A Feather',
#  'Beautiful Things',
#  'Shake It To The Max (Fly)',
#  'Love Me Not',
#  'What I Want',
#  'Espresso',
#  'Triple Lavada',
#  'Undressed',
#  'Pink Pony Club',
#  'Wildflower',
#  'That’s So True',
#  'Mystical Magical',
#  'Just In Case',
#  'No Tiene Sentido',
#  'Azizam',
#  'Nokia',
#  'Marlboro Rojo',
#  'No One Noticed',
#  'Gnarly',
#  'Anxiety',
#  'Sailor Song',
#  'Si Antes Te Hubiera Conocido',
#  'All The Stars',
#  'Party 4 U',
#  'Creep',
#  'Dreams',
#  'Blue Strips',
#  'Taste',
#  'Fame Is A Gun',
#  'Mutt',
#  'EOO',
#  'Yellow',
#  'Perfect',
#  'Gata Only',
#  'Please Please Please',
#  'I Got Better',
#  'Sweater Weather',
#  'Viva La Vida',
#  'Nuevayol',
#  'Snooze',
#  'Cruel Summer',
#  'Capaz',
#  'Luna Bala',
#  'Who',
#  'As It Was',
#  'Me Jalo',
#  'Blinding Lights',
#  'Take On Me',
#  'Move',
#  'Te Queria Ver',
#  "Sorry I'm Here For Someone Else",
#  'Chihiro',
#  'See You Again',
# ...

# %%
artits
# Out:
# ['Alex Warren',
#  'Lady Gaga & Bruno Mars',
#  'Billie Eilish',
#  'Benson Boone',
#  'MOLIY, Silent Addy, Skillibeng & Shenseea',
#  'Ravyn Lenae',
#  'Morgan Wallen Featuring Tate McRae',
#  'Sabrina Carpenter',
#  'Esau Ortiz',
#  'sombr',
#  'Chappell Roan',
#  'Billie Eilish',
#  'Gracie Abrams',
#  'Benson Boone',
#  'Morgan Wallen',
#  'Beele',
#  'Ed Sheeran',
#  'Drake',
#  'Fuerza Regida',
#  'The Marias',
#  'KATSEYE',
#  'Doechii',
#  'Gigi Perez',
#  'Karol G',
#  'Kendrick Lamar & SZA',
#  'Charli xcx',
#  'Radiohead',
#  'Fleetwood Mac',
#  'Jessie Murph',
#  'Sabrina Carpenter',
#  'Addison Rae',
#  'Leon Thomas',
#  'Bad Bunny',
#  'Coldplay',
#  'Ed Sheeran',
#  'FloyyMenor X Cris Mj',
#  'Sabrina Carpenter',
#  'Morgan Wallen',
#  'The Neighbourhood',
#  'Coldplay',
#  'Bad Bunny',
#  'SZA',
#  'Taylor Swift',
#  'Alleh & Yorghaki',
#  "Yb Wasg'ood & Ariis",
#  'Jimin',
#  'Harry Styles',
#  'Fuerza Regida & Grupo Frontera',
#  'The Weeknd',
#  'a-ha',
# ...

# %%
print(len(tp_song))
print(len(artits))
# Out:
# 100
# 100

# %%
song_dict={'Songs':tp_song,'Artist': artits}
song_df=pd.DataFrame(song_dict)
song_df
# Out:
#                         Songs                                     Artist
# 0                    Ordinary                                Alex Warren
# 1            Die With A Smile                     Lady Gaga & Bruno Mars
# 2          Birds Of A Feather                              Billie Eilish
# 3            Beautiful Things                               Benson Boone
# 4   Shake It To The Max (Fly)  MOLIY, Silent Addy, Skillibeng & Shenseea
# ..                        ...                                        ...
# 95          Until I Found You                            Stephen Sanchez
# 96                  Worst Way                                Riley Green
# 97                  The Chain                              Fleetwood Mac
# 98                     Cliche                                        mgk
# 99      I Remember Everything       Zach Bryan Featuring Kacey Musgraves
#
# [100 rows x 2 columns]

# %%
print(song_df)
# Out:
#                         Songs                                     Artist
# 0                    Ordinary                                Alex Warren
# 1            Die With A Smile                     Lady Gaga & Bruno Mars
# 2          Birds Of A Feather                              Billie Eilish
# 3            Beautiful Things                               Benson Boone
# 4   Shake It To The Max (Fly)  MOLIY, Silent Addy, Skillibeng & Shenseea
# ..                        ...                                        ...
# 95          Until I Found You                            Stephen Sanchez
# 96                  Worst Way                                Riley Green
# 97                  The Chain                              Fleetwood Mac
# 98                     Cliche                                        mgk
# 99      I Remember Everything       Zach Bryan Featuring Kacey Musgraves
#
# [100 rows x 2 columns]

# %%
song_df.head(60)
# Out:
#                               Songs                                     Artist
# 0                          Ordinary                                Alex Warren
# 1                  Die With A Smile                     Lady Gaga & Bruno Mars
# 2                Birds Of A Feather                              Billie Eilish
# 3                  Beautiful Things                               Benson Boone
# 4         Shake It To The Max (Fly)  MOLIY, Silent Addy, Skillibeng & Shenseea
# 5                       Love Me Not                                Ravyn Lenae
# 6                       What I Want         Morgan Wallen Featuring Tate McRae
# 7                          Espresso                          Sabrina Carpenter
# 8                     Triple Lavada                                 Esau Ortiz
# 9                         Undressed                                      sombr
# 10                   Pink Pony Club                              Chappell Roan
# ...

# %%
song_df.describe()
# Out:
#            Songs             Artist
# count        100                100
# unique       100                 80
# top     Ordinary  Sabrina Carpenter
# freq           1                  4

# %%
df_song = pd.read_csv(r"C:\Users\samya\Downloads\audio_features_dataset_curated.csv")

# %%
df_song.head()
# Out:
#                  track_id                 artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# ...

# %%
df_song.nunique()
# Out:
# track_id            34478
# artists             12562
# album_name          17915
# track_name          27352
# popularity            101
# duration_ms         22332
# explicit                2
# danceability          932
# energy               1572
# key                    12
# loudness            12582
# mode                    2
# speechiness          1229
# acousticness         3956
# instrumentalness     4772
# liveness             1623
# valence              1559
# tempo               21252
# time_signature          5
# dtype: int64

# %%
df_song.isnull().sum()
# Out:
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# dtype: int64

# %%
def ms_to_mmss(ms):
    minutes = ms // 60000
    seconds = (ms % 60000) // 1000
    return f"{minutes:02}:{seconds:02}"
df_song['duration_mmss'] = df_song['duration_ms'].apply(ms_to_mmss)

# %%
df_song.dropna(inplace=True)

# %%
df_song.describe()
# Out:
#          popularity   duration_ms  danceability        energy           key  \
# count  42999.000000  4.299900e+04  42999.000000  42999.000000  42999.000000
# mean      34.186749  2.308657e+05      0.575397      0.632785      5.345985
# std       25.826423  9.284903e+04      0.166244      0.241945      3.559563
# min        0.000000  1.745300e+04      0.000000      0.000020      0.000000
# 25%        1.000000  1.811060e+05      0.465000      0.475000      2.000000
# 50%       39.000000  2.168070e+05      0.587000      0.674000      6.000000
# 75%       54.000000  2.613595e+05      0.700000      0.832000      8.000000
# max      100.000000  3.601693e+06      0.975000      1.000000     11.000000
#
#            loudness          mode   speechiness  acousticness  \
# count  42999.000000  42999.000000  42999.000000  42999.000000
# mean      -7.915887      0.645527      0.071419      0.299393
# std        4.712461      0.478359      0.072020      0.322862
# ...

# %%
df_song.columns
# Out:
# Index(['track_id', 'artists', 'album_name', 'track_name', 'popularity',
#        'duration_ms', 'explicit', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'duration_mmss'],
#       dtype='object')

# %%
df_song.dtypes
# Out:
# track_id             object
# artists              object
# album_name           object
# track_name           object
# popularity            int64
# duration_ms           int64
# explicit               bool
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature        int64
# duration_mmss        object
# dtype: object

# %%
df_song
# Out:
#                      track_id                 artists  \
# 0      5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1      4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2      1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3      6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4      5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...                       ...                     ...
# 42995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 42996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 42997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 42998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 42999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                               album_name  \
# 0                                                 Comedy
# 1                                       Ghost (Acoustic)
# 2                                         To Begin Again
# 3      Crazy Rich Asians (Original Motion Picture Sou...
# ...

# %%
df_song.nunique()
# Out:
# track_id            34477
# artists             12562
# album_name          17915
# track_name          27352
# popularity            101
# duration_ms         22331
# explicit                2
# danceability          932
# energy               1572
# key                    12
# loudness            12582
# mode                    2
# speechiness          1229
# acousticness         3956
# instrumentalness     4772
# liveness             1623
# valence              1559
# tempo               21251
# time_signature          5
# duration_mmss         693
# dtype: int64
